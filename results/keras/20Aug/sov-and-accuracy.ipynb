# %% [markdown]
# # Shared functions

# %%
import os
import pickle
import pandas as pd
import numpy as np
import subprocess

# %%
# Write function calc() that outputs:
# 1. HMM Q3 accuracy (N matches/N total)
# 2. PSSM Q3 accuracy
# 3. HMM SOV (call calSOV binary from python) 
# 4. PSSM SOV
# 
# Given the following arguments
# 1. sequence
# 2. dssp
# 3. hmm prediction
# 4. pssm prediction

def calc(outfolder,scopeID,seq,dssp,hmm_pred,pssm_pred): 
    n=len(seq)
    assert n!=0
    assert all(_==n for _ in [len(dssp),len(hmm_pred),len(pssm_pred)])
    hmm_pred=hmm_pred.replace('-','C')
    pssm_pred=pssm_pred.replace('-','C')
    dssp=dssp.replace('-','C')
    # write two sov.in file
    hmm_sov_in=os.path.join(outfolder,'%s.hmm.sov.in' % scopeID)
    pssm_sov_in=os.path.join(outfolder,'%s.pssm.sov.in' % scopeID)
    with open(hmm_sov_in,'w+') as f_hmm, open(pssm_sov_in,'w+') as f_pssm:
        f_hmm.write("AA  OSEC PSEC\n")
        f_pssm.write("AA  OSEC PSEC\n")
        for (aa,osec,psec_hmm,psec_pssm) in zip(seq,dssp,hmm_pred,pssm_pred): # no commas allowed
            f_hmm.write("%s   %s    %s\n" % (aa,osec,psec_hmm))
            f_pssm.write("%s   %s    %s\n" % (aa,osec,psec_pssm))

    hmm_sov_out=os.path.join(outfolder,'%s.hmm.sov.out' % scopeID)
    pssm_sov_out=os.path.join(outfolder,'%s.pssm.sov.out' % scopeID)

    cmd_hmm="calSOV -f 1 %s -o %s" % (hmm_sov_in,hmm_sov_out) # must have calSOV installed and path configured
    cmd_pssm="calSOV -f 1 %s -o %s" % (pssm_sov_in,pssm_sov_out)
    proc_hmm=subprocess.run(args=cmd_hmm.split())
    proc_pssm=subprocess.run(args=cmd_pssm.split())

    assert proc_hmm.returncode==0
    assert proc_pssm.returncode==0
    assert os.path.exists(hmm_sov_out)
    assert os.path.exists(pssm_sov_out)

    with open(hmm_sov_out,'r') as f:
        lines=f.read().splitlines()
        ans=lines[1].split()
        hmm_sov,hmm_acc=ans[1],ans[10]
        
    assert os.path.exists(pssm_sov_out)
    
    with open(pssm_sov_out,'r') as f:
        lines=f.read().splitlines()
        ans=lines[1].split()
        pssm_sov,pssm_acc=ans[1],ans[10]
    
    assert(_!="nan" & _!="-nan" for _ in [hmm_sov,hmm_acc,pssm_sov,pssm_acc])    
    
#    del_cmd='rm %s %s %s %s' % (hmm_sov_in, hmm_sov_out, pssm_sov_in, pssm_sov_out)
#    proc_del=subprocess.run(args=del_cmd.split())
#    assert proc_del.returncode==0    
    
    return tuple([float(v) for v in (hmm_acc,pssm_acc,hmm_sov,pssm_sov)])

# %% [markdown]
# # Keras

# %%
for i in range(1,8):

    # read hmm predictions
    hmm_preds_pkl="/cluster/gjb_lab/2472402/outputs/keras_train_CV/HMM/20Aug/cv%d/results.pkl" % i
    assert os.path.exists(hmm_preds_pkl)
    with open(hmm_preds_pkl,'rb') as f:
        (_,(scopeIDs,_,_,hmm_preds))=pickle.load(f)

    # read pssm predictions
    pssm_preds_pkl="/cluster/gjb_lab/2472402/outputs/keras_train_CV/PSSM/20Aug/cv%d/results.pkl" % i    
    assert os.path.exists(pssm_preds_pkl)
    with open(pssm_preds_pkl,'rb') as f:
        (_,(scopeIDs2,_,_,pssm_preds))=pickle.load(f)
    
    assert all([s1==s2 for (s1,s2) in zip(scopeIDs,scopeIDs2)])
    results=[]
    alignments=[]

    for (scopeID,hmm_probabilities,pssm_probabilities) in zip(scopeIDs,hmm_preds,pssm_preds):

        # f: [0.005 0.005 0.98] -> 2, [0.3,0.4,0.3] -> 1, [0.8, 0.1, 0.1] -> 0
        # g: [2,1,0] -> ['-','E','H']
        # h: ['H','H','E,'C','H'] -> 'HHE-H'
        f=lambda arg: np.apply_along_axis(np.argmax,1,arg) 
        g=lambda args: [['H','E','-'][arg] for arg in args] 
        h=lambda arg: ''.join(arg) 

        # convert probability distribution into prediction string
        hmm_pred=h(g(f(hmm_probabilities)))
        pssm_pred=h(g(f(pssm_probabilities)))

        data_folder="/homes/adrozdetskiy/Projects/jpredJnet231ReTrainingSummaryTable/data/training/"
        sec_file=data_folder+scopeID+'.sec'

        assert os.path.exists(sec_file)
        with open(sec_file,'r') as f:
            sec=f.read().splitlines()
            seq=sec[0].replace("SEQUENCE:","").replace(",","")
            dssp=sec[1].replace("DSSP:","").replace("B","E").replace("I","-").replace("G","-").replace("S","-").replace("T","-").replace(",","")

        # check sanity of input to calc()
        print("scopeID:   %s" % scopeID)
        print("DSSP:      %s" % dssp)
        print("HMM pred:  %s" % hmm_pred)
        print("PSSM pred: %s" % pssm_pred)

        sov_folder='/cluster/gjb_lab/2472402/sov/keras/20Aug/cv%d/' % i
        assert os.path.exists(sov_folder)
        (hmm_acc,pssm_acc,hmm_sov,pssm_sov)=calc(sov_folder,scopeID,seq,dssp,hmm_pred,pssm_pred)

        # check sanity of output of calc()
        print("output of calc: ")
        print("HMM acc:   %s" % hmm_acc)
        print("PSSM acc:  %s" % pssm_acc)
        print("HMM SOV:   %s" % hmm_sov)
        print("PSSM SOV:  %s" % pssm_sov)

        #store results
        results.append((scopeID,hmm_acc,pssm_acc,hmm_sov,pssm_sov))
        alignments.append((scopeID,seq,dssp,hmm_pred,pssm_pred))


    # output results to csv file
    out_file="/cluster/gjb_lab/2472402/results/keras/20Aug/cv%i_scores.csv" % i
    with open(out_file,'w+') as f:
        f.write("scopeID,HMM_acc,PSSM_acc,HMM_sov,PSSM_sov\n")
        for (scopeID,hmm_acc,pssm_acc,hmm_sov,pssm_sov) in results:
            line="%s,%.2f,%.2f,%.2f,%.2f\n" % (scopeID,hmm_acc,pssm_acc,hmm_sov,pssm_sov)
            f.write(line)

    # write alignments to kerasnet file
    align_file="/cluster/gjb_lab/2472402/results/keras/20Aug/cv%i.knet" % i
    with open(align_file,'w+') as f:
        for (scopeID, seq,dssp,hmm_pred,pssm_pred) in alignments:
            f.write("scopeID   : %s\n" % scopeID)
            f.write("sequence  : %s\n" % seq)
            f.write("DSSP      : %s\n" % dssp)
            f.write("HMM_pred  : %s\n" % hmm_pred)
            f.write("PSSM_pred : %s\n" % pssm_pred)
# Out:
# scopeID:   d2ia7a1
# DSSP:      ------HHHHHHHHHHHHH--------------------------HHHHHHHHHHHHHHHHHH---EEEEEEEEE-------EEEEEEEEEE----EEEEEEEEEE-----
# HMM pred:  --EEEHHHHHHHHHHHHHH------------H---HHHHH-----HHHHHHHHHHHHHHHHHH---EEEEEEEEEE------EEEEEEEEEEE----EEEEEEEEEE----
# PSSM pred: -EEEEE-HHHHHHHHHHHH------EEE-------HHHHH-----HHHHHHHHHHHHHHHHH----EEEEEEEEEE-----EEEEEEEEEEEEE---EEEEEEEEEE----
# output of calc:
# HMM acc:   87.39
# PSSM acc:  81.08
# HMM SOV:   68.1
# PSSM SOV:  64.05
# scopeID:   d3rq7a1
# DSSP:      -HHHHHHHHHHHHH--------------E---------EEEEEEE----EEEEEE----EEEEE----EEEE-----EEEEE-----EEEEE--------HHHHHHHHHHHHHHHH---------
# HMM pred:  --HHHHHHHHHHH----HH-----------------EEEEEEEE-----EEEEEE----EEEEE----EEEE-----EEEEEE----EEEE------HHHHHHHHHHHHHHHHHHHHH-------
# PSSM pred: -HHHHHHHHHHHH---HHH-----------------EEEEEEEE-----EEEEEEE---EEEEE----EEEEE----EEEEEE------EE------HHHHHHHHHHHHHHHHHHHHH-------
# output of calc:
# HMM acc:   88.0
# PSSM acc:  84.8
# HMM SOV:   86.09
# PSSM SOV:  83.16
# scopeID:   d3rjsa_
# DSSP:      ----EEEEEE--HHHHHHHHHHHHHHHHH---HHHHHHHHHHHHHHHH----EEEEE--------EEEEEEEEEEE--EEEEEEEE-
# HMM pred:  --EEEEEE----HHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHH----EEEEEE---EEEEEE----EEEEEE--EEEEEEE--
# PSSM pred: --EEEEE-----HHHHHHHHHHHHHHHHH-----HHHHHHHHHHHH-----EEEEEE----EEEEE----EEEEEE--EEEEEEE--
# output of calc:
# HMM acc:   80.46
# PSSM acc:  78.16
# HMM SOV:   81.25
# PSSM SOV:  80.26
# scopeID:   d1kqfb2
# DSSP:      --HHHHHHH--HHHHHHHHHHHHHHHHHHHHHHH--E--------
# HMM pred:  ---H--H---HHHHHHHHHHHHHHHHHHHHHHH-------HHH--
# PSSM pred: --HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH------------
# output of calc:
# HMM acc:   75.56
# PSSM acc:  91.11
# HMM SOV:   59.76
# PSSM SOV:  79.46
# scopeID:   d3c8wa1
# DSSP:      -EEE-------------------------EEEEEEEEEEEEEE--HHHHHHH----EEE---EEEEEEEEEEEE---EEEEEEEEEEEEEE--EEEEEEEEEEE--HHHHHHHHH-----EEE-EEEEEEE--EEEEEEEE--EEEEEEEEE---EE--HHHHHHHH---EEEEEEEE-----EEEEEEEEE--EEEEEEEEEE--EEEEE--------------EEEEEEEEEEEEEE---EEEEE---
# HMM pred:  -------EEE--EEEEE-------------EE--EEEEEEEEE--HHHHH--------E---EEEEEEEE-----------EEEEEEEEEE--EEEEEEEEEE----HHHHHHHHHH----EEEEEEEEE---EEEEEEEE----EEEEEEE------------------EEEEEEE------------EEEE---EE--EEEEEEEEEEE--------------EEEEEEEEEEEEEE----EEEE---
# PSSM pred: -------EEE---EEE--------------EEEEEEEEEEEEEE-HHHHH------------EEEEEEEE-----------EEEEEEEEE---EE-EEEEEEE----HHHHHHHHHH----EEEEEEEEE---EEEEEEE---EEEEEEEEE----------H--------EEEEEE-------------EEEEEEEEEEEEEEEEEEEEE--------------EEEEEEEEEEEEE-----HHHHH--
# output of calc:
# HMM acc:   76.0
# PSSM acc:  74.8
# HMM SOV:   64.21
# PSSM SOV:  63.02
# scopeID:   d1io1a_
# DSSP:      --HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHHHHHHHHHH--E--E------EEEEEE-------EEEEEE-------------------EEEEEE-----EEEEEEE-E--------------EEEE---EEEE----EEEEEEEEE------EEEEEEE-----EEEE-----------------EEE-EEEEE----HHHHHHHHH------EEEEEEEEE-----EEEEEEEEEE--EEEEEEE-----EEE-E--EE------E--EEEEE-----EEEEEE--EEEEHHHH---E-----------------HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH---
# HMM pred:  ----HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHHHHHHHH-------EE--------EEEEEE----EEEEEE---EE-------EEEEE---------EEEE------EEE---EEEEEEE-------------------EEEEE-EEEEE-EEEEEEE----EEE--------------EEE----E--EEEEE--E--------EE-------------EEEEE----EEEE-E--EEEE--EEEE----------------------EEEEEE--EEEEE-E-----EEEE--------------EEE---HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--
# PSSM pred: ----HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH-------HHHHHHHHHHHHHHHHHHHHHHHHHH----EEE------EEEEE--------EEEEEEE-------------E--------EE--------------EEEEE-------------HHE-------EEEEEEE-------EEEEEEE---------------------E-----------EE------------H-----------EE--------------------EEEEE----------EEEEE-------------EEE---------EE--HHHHH-----------------HHHHHHHHHHHHHHHHHHHH-HHHHHHHHHHHHHHHHHHHHHHHHH--
# output of calc:
# HMM acc:   66.58
# PSSM acc:  67.09
# HMM SOV:   52.75
# PSSM SOV:  58.49
# scopeID:   d1l3ka1
# DSSP:      -------EEEEE-------HHHHHHHH-----EEEEEEEE------EEEEEEEEE--HHHHHHHHH----EE--EE-EEEE---
# HMM pred:  -------EEEEE-------HHHHHHHH-----EEEEEEEE---------EEEEEE--HHHHHHHHH----EE---EEEEEEE--
# PSSM pred: -------EEEEE-------HHHHHHHHH----EEEEEEEE---------EEEEEE--HHHHHHHHH-----E--EEEEEEE---
# output of calc:
# HMM acc:   92.86
# PSSM acc:  92.86
# HMM SOV:   96.34
# PSSM SOV:  95.58
# scopeID:   d2h8ea_
# DSSP:      --EEEEEEE----HHHHEEE----EEE-HHHHHHHHHHHHHHHH------E---EEEEEEEE---------HHHHHHHHHHHHHH--E-----EEEEEEEEE------EEEEEEEE----
# HMM pred:  --EEEEEEE--------EE-----EE--HHHHHHHHHHHHHHHHHH-------EEEEEEEEEE----------HHHHHHHHH---EEEE----EEEEEEEEEEE----EEEEEEEE----
# PSSM pred: --EEEEEE---------EE-----EEE--HHHHHHHHHHHHHHHHH-------EEEEEEEEE----------HHHHHHHHHH---EEEE----EEEEEEEEEEE----EEEEEEEE----
# output of calc:
# HMM acc:   82.5
# PSSM acc:  83.33
# HMM SOV:   88.78
# PSSM SOV:  89.34
# scopeID:   d1o98a1
# DSSP:      -HHHHHHHHHH-------HHHHHHHHHHHHH---EEEEEE---------HHHHHHHHHHHHH-----EEEEEEE---------HHHHHHHHHHHHHHH---EEEEEEEHHHH------HHHHHHHHHHHHH----EE--HHHHHHHHHH----------EEEE-----E--------EEEE--------HHHHHHHH-----------------EEEE----------EE----
# HMM pred:  ----HHHHHH-------HHHHHHHHHHHHH----EEEEEE------HHHHHHHHHHHHHHHHH-----EEEE----------HHHHHHHHHHHHHHH---EEEEEEE-EEE--------HHHHHHHHHHH---------HHHHHHHHHH------EEEEEEEE-------EEE----EEEEE-----HHHHHHHHH------------EE----EEEEEEE-------------
# PSSM pred: ----HH-HHHH------HHHHHHHHHHHHH---EEEEEEEE--------HHHHHHHHHHHHHH---EEEEEEE--------HHHHHHHHHHHHHHHH---EEEEEEEEEEEE------HHHHHHHHHHHH---------HHHHHHH----------EE-EEEE--------EE----EEEEEE----HHHHHHHHHH-----------------EEEEEEE-------------
# output of calc:
# HMM acc:   81.2
# PSSM acc:  83.33
# HMM SOV:   82.94
# PSSM SOV:  79.99
# scopeID:   d1p9ga_
# DSSP:      ---------------EEE----EE--HHHH----EEE----
# HMM pred:  ----HH-------------E---------------------
# PSSM pred: -----------------------------------------
# output of calc:
# HMM acc:   63.41
# PSSM acc:  70.73
# HMM SOV:   36.02
# PSSM SOV:  24.27
# scopeID:   d4gv2a1
# DSSP:      ---EE------HHHHHHHHHH--HHHHHHHHHH--E-----------HHHHHHHHHHHHHHHHHH------HHHHHHHHHHH--E------------HHHHHHHHHHHHHHHHHHHHHHH----HHHHH--EE--HHHHHHHH
# HMM pred:  -----------HHHHHHHHHHH-HHHHHHHHHHH-------------HHHHHHHHHHHHHHHHHH----HHHHHHHHHHHEEE--------------HHHHHHHHHHHHHHHHHHHHHHHHHH------------HHHHHH--
# PSSM pred: -----------HHHHHHHHHHHHHHHHHHHHHHHH----------HHHHHHHHHHHHHHHHHHHH----HHHHHHHHHHHHHH--------------HHHHHHHHHHHHHHHHHHHHHHHHH--H-----------HHH----
# output of calc:
# HMM acc:   83.92
# PSSM acc:  81.82
# HMM SOV:   82.58
# PSSM SOV:  76.12
# scopeID:   d1cipa1
# DSSP:      --HHHHHH-HHHHHHHHHHHHHHHHHHHHHH--------HHHHHHHHHHHHHHH------HHHHHHHHHHHH-HHHHHHH-----------HHHHH--HHHH--------HHHHH------
# HMM pred:  --HHHHHHHHHHHHHHHHHHHHHHHHHHHH----------HHHHHHHHH-----------HHHHHHHHHHH--HHHHHHHHH----------HHHHHHHHHH--------HHHHHHEE---
# PSSM pred: --HHHHHHHHHHHHHHHHHHHHHHHHHHHHH--------HHHHHHHEEE-----------HHHHHHHHHH---H-HHHHHHH---HHHH-----HHHHHHHHH-------HHHHHHHE---
# output of calc:
# HMM acc:   85.95
# PSSM acc:  77.69
# HMM SOV:   86.33
# PSSM SOV:  69.64
# scopeID:   d2deja2
# DSSP:      -EEEEEEE-----HHHHHHHHHHHHHHHHH-----------------HHHHHHHHHHHHHHHHHHHHHHHHH---HHHHHHHHHHHHHHHHH------HHHHHHHHHHHH----EEEE-------EEEEEEE---HHHHHHHHHHHHHHH-----EEEEE-EE---E-
# HMM pred:  -EEEEEEE--------HHHHHHHHHHHHHH---------HHHHH---HHHHHHHHHHHHHHHHHHHHHHHHHH--HHHHHHHHHHHHHHHHHHH---HHHHHHHHHHHHH----EEEEE------EEEEE-----HHHHHHHHHHHHHH------EEEEEE-----EE
# PSSM pred: --EEEEEE--------HHHHHHHHHHHHHH---------HHH-----HHHHHHHHHHHHHHHHHHHHHHHHH---HHHHHHHHHHHH-------E---HHHHHHHHHHHHH---EEEE-------EEEEE----HHHHHHHHHHHHHHHH-----EEEEEE-----E-
# output of calc:
# HMM acc:   88.1
# PSSM acc:  88.1
# HMM SOV:   86.31
# PSSM SOV:  86.52
# scopeID:   d1e44b_
# DSSP:      -HHHHH-----------------EEEE----E------E--EEEE----EEEEEE----EEEEEE----EEEEEE------E--------E-----
# HMM pred:  --------EE------------------------------EEEE-----EEEEEE----EEEEE------EEEEEE--------------------
# PSSM pred: -------------------------------EEE-------EEE-----EEEEEE----EEEEEE----EEEEEEE--------------------
# output of calc:
# HMM acc:   79.17
# PSSM acc:  83.33
# HMM SOV:   52.34
# PSSM SOV:  65.84
# scopeID:   d1vioa2
# DSSP:      -EEHHHHHHHHH---HHHHHHHHH---EEE--EE------EE-----EEE--EE--------EEEEEE----E-------E-------------EE--------EEEEEEE--HHHHHHHH-------EEEEEEE-------HHHHHHH--------------EEEE----EEEEEE------HHHHHHHH----EEEEEEEEE--EE---------EEE--HHHHHH--
# HMM pred:  -HHHHHHHHH-----HHHHHHHHHH--EEE--EEE-----E-----EEEE-----------EEEEE-----EEEE-------EEE----------EEEE------EEEEEE--HHHHHHHHH------EEEEEEEE----HHHHHHHHH-----------EEEEEEE----EEEEEEE----HHHHHHHHH----EEE--EEE----E---------EE---HHHHHHH-
# PSSM pred: --HHHHHHHHH----HHHHHHHHHH---EE---EEE-----------HHHHHHHHH-HH-H-EEEE------E---------EEEEE-------EE----------EEEEE--HHHHHHHHHHH----EEE-EEEE----HHHHHHHHH---------EEE------------EEEE------HHHHHHHHH---EEEEEEEEE---E--------------HHHHHHH-
# output of calc:
# HMM acc:   82.61
# PSSM acc:  76.52
# HMM SOV:   84.3
# PSSM SOV:  68.53
# scopeID:   d1r5la1
# DSSP:      ---HHHHHHHHHHH----------HHHHHHHHHH----HHHHHHHHHHHHHHHHH-HHHH------
# HMM pred:  HHHHHHHHHHHHH-----------HHHHHHHH------HHHHHHHHHHHHHHHHH-HHHH------
# PSSM pred: HHHHHHHHHHHHH-----------HHHHHHHHH------HHHHHHHHHHHHHHHHHHHHH------
# output of calc:
# HMM acc:   90.91
# PSSM acc:  89.39
# HMM SOV:   95.45
# PSSM SOV:  89.61
# scopeID:   d3bula1
# DSSP:      ------E---EE------EE-----------EEE---EEEEEEE------EEE--EEE-------------------------------HHHH--EEEEEEEEE---EEEEEEE-----------EEEE------EEEE-----EEEEE------EEEEEEE---EEEEEE----EE----EEEEEEE-EEEEEEEE--
# HMM pred:  -----E-----EEE-----EE----------------EEEEEEE---------EEEEE------EEEE--------------------EEHH--EEEEEEEE-----EEEEEEE-----------EEEEE----EEEEE----EEEEEEEE-----EEEEEE---EEEEE-----------EEE---------------
# PSSM pred: ----EE-----EEEE----EE----------------EEEEEEE---------EEEEEE------EEE-------------------EEE-----EEEEEEEE-----EEEEEE-----------EEEEEE---EEEEEE---EEEEEEEE-----EEEEEE---EEEE------------EEEEE------EE-----
# output of calc:
# HMM acc:   76.88
# PSSM acc:  75.38
# HMM SOV:   72.96
# PSSM SOV:  71.63
# scopeID:   d2b1ya1
# DSSP:      ---------------------------------HHHHHHHHHH----------------------------------------------------------
# HMM pred:  ----EEEEE--------EEEEEE---EEEEEE------H------------------EEEEE-----EEEEEE-------EEEEEEEE-------------
# PSSM pred: -----EE---------EEEEEEE----EEEEE--HHHHHHH------EE---E----EEEEE----EEEEEEE------EEEEEEEEE-------------
# output of calc:
# HMM acc:   55.45
# PSSM acc:  59.41
# HMM SOV:   21.99
# PSSM SOV:  18.1
# scopeID:   d2bhua2
# DSSP:      ----EEEEEE--EEEEEEEE--EEEEEEEE-----EE-------------EEEE-------EE----EEEE-
# HMM pred:  ------------EEEEEE-----EEEEEE----------------------EEE-------------EEE--
# PSSM pred: ------------EEEEEEE-----EEEEEE---------EEE--------EEEE-------------EEE--
# output of calc:
# HMM acc:   77.78
# PSSM acc:  76.39
# HMM SOV:   67.01
# PSSM SOV:  63.43
# scopeID:   d2iafa1
# DSSP:      ----HHHHHHHHHHHHHHHH--------EEEEEEEHHHHH------HHHHHHHH--------HHHHHHHHHHH-EEEE---EEEE--HHHHEEEE----------EEEEEEE-----EEEEEEEEE-----EEE------
# HMM pred:  ----HHHHHHHHHHHHHHHH--------EEEEEEE--HH-H------HHHHHHHH-----------HHHHHH------------------EEEEE----------EEEEEEE-----EEEEEEEEEE---EEEEE-----
# PSSM pred: ----HHHHHHHHHHHHHHHH-------EEEEEEEE--HHHH-----HHHHHHHHH---------HHHHHHHH-----------EEEE---EEEEE----------EEEEEEE-----EEEEEEEEEE---EEEEE-----
# output of calc:
# HMM acc:   81.43
# PSSM acc:  83.57
# HMM SOV:   83.42
# PSSM SOV:  88.15
# scopeID:   d1xlya_
# DSSP:      --E----HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHHHHHHHHH-------------------EHHHHHHHHHHHHHHHHHHHHHHHHHHH-HHHHHHHHHH--------HHHHHHHHHHHHHHHHHHHHHHHH----------HHHHHHHH-----------------HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--
# HMM pred:  -EEE-HHHHHHHHHHHHHHHHHHH-HHHHHHHHHHHHHHHH---HHHHHHHHHHHHHHHH-HHHHHEE-H--------------HHHHHHHHHHHHHHHHHHHHHHHHHHHH-----HHHHHHH--------HHHHHHHHH----EEHHHHHHHHH---------EEEHHHHHHHHHH-------EEEE--HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# HMM pred:  -EEEEEEE---------HHHHHHHHHHHH------EEEEE-----HHHHHHH----EEEEEEEE--------EEEEEE------------------HHHHHHHHHHH------EEEEEEEE-EE-------HHHHHHHHHHHHHHHHHHHH----EEE----
# PSSM pred: --EEEEEE---------HHHHHHHHHHHH------EEEEEE-----HHHHHH----EEEEEEEE-------EEEEEE-------------------HHHHHHHHHHH------EEEEEEEEEEE-------HHHHHHHHHHHHHHHHHHHH----EEE----
# output of calc:
# HMM acc:   79.63
# PSSM acc:  79.63
# HMM SOV:   77.02
# PSSM SOV:  79.97
# scopeID:   d2ofca_
# DSSP:      -EEEEEEEEE------EEEEEEEE------EEEEEE--EEEEEE-----EEEEEEEE----EEEEEEEEE--EEEEEEEE-------HHHHHHH----HHHHHHHH----EEEEE-----EEEEEEEE----EEEEEEEE-
# HMM pred:  -EEEEEEEEE-----EEEEEE---EEE----EEEE---EEEEEE-----HHHEEE------EEEEEEEE--------EEEE------EEEE------------HHHHH------------EEEEEEEE----EEEEEEEE-
# PSSM pred: -EEEEEEEEE-----EEEEEE---EEE-----E-----EEEEEE-----E-EEEEE-----EEEEEEEE-------EEEEEE-----EEEE--------------HH-----EE------EEEEEEEE----EEEEEEEE-
# output of calc:
# HMM acc:   71.63
# PSSM acc:  72.34
# HMM SOV:   75.64
# PSSM SOV:  74.06
# scopeID:   d1jida_
# DSSP:      -----------EEE-----E----------------E----HHHHHHHHHH----EEEE-----------------EEEE--E-----E-------HHHHHHHHHHH-------
# HMM pred:  ----------EEEEEE----------------H--------HHHHHHHHHH----EEE------------------EEEEEEE------E------HHHHHHHHHHHHH-----
# PSSM pred: ----------EEEEEEEE------HHHHHH--HH-------HHHHHHHHHH----EEEE----------------EEEEEEE--------------HHHHHHHHHHHHHH----
# output of calc:
# HMM acc:   88.6
# PSSM acc:  79.82
# HMM SOV:   81.95
# PSSM SOV:  63.1
# scopeID:   d1xaka_
# DSSP:      -EEEEEEEEE---EEEEE------EEEE-----EE---EEEEE---EEEEEE-----EEEEEEEEE--
# HMM pred:  ---HHHH------EEEE----------------------EEEEE----EEEEE-----EEEEEE----
# PSSM pred: ------HHHHHHHHHHH----------------------EEEEE---EEEEEE------EEEEE----
# output of calc:
# HMM acc:   64.71
# PSSM acc:  54.41
# HMM SOV:   57.89
# PSSM SOV:  45.28
# scopeID:   d4fyxb1
# DSSP:      ---E-----EEEEEEE----HHHHHHH---------EEEEEEEEE---EEEEEEEEE-----HHHHH---------EEEEEE--EEEEEE-----
# HMM pred:  ----------EEEE-------HHHHHHH-------EEEEEEE----------EEEE------HHHHHEEEEE----EEEEEE--EEEEEE-----
# PSSM pred: ---E------EEEEE-----HHHHHHH--------EEEEEEE----------EEEE----------EEEEEE---EEEEEEE--EEEEEE-----
# output of calc:
# HMM acc:   78.95
# PSSM acc:  76.84
# HMM SOV:   84.66
# PSSM SOV:  81.89
# scopeID:   d3ge3e_
# DSSP:      -HHHHHHH---EEEEEEE----HHHHHHHHHHH------EEEE---EEEEEEE-EEEEEHHHHHHHH------------EEEEE-EEEE---EEEEE-----
# HMM pred:  -------------EEEE-----HHHHHHHHHHH----EEEEE----EEEEE---EEEE-HHHHHHHH--------EEEEEEEEEEEEEE---EEEEEE----
# PSSM pred: ------------EEEEEE-----HHHHHHHHH-----EEEEEE---EEEEE---EEEEEHHHHHHHH--------EEEEEEEEEEEEEEE--EEEEEE----
# output of calc:
# HMM acc:   78.43
# PSSM acc:  79.41
# HMM SOV:   82.24
# PSSM SOV:  82.84
# scopeID:   d4eada2
# DSSP:      ----------EEEEEE-------HHHHHHHHHHH---EEEEE----E--E--HHHHH-----------HHHHHHHHHHH-EEEE-------HHHHHHHHHH--------HHHHHHHHHHHHH-----EEEEEEEE--------HHHHHHHHHHHHHHHHH---EEEEEEEE--------EE-HHHHHHHHHHHH-----HHHHHHHHHHHHHHHHH------HHHHHHHHHHHHH--HHHHHHHHHHHH------HHHHHHHH--
# HMM pred:  ----EE----EEEEE--------HHHHHHHHHHH------------------HHHHHHH---------HHHHHHHHHHH--EEE--------------------------------------------EEEEEEE---EEE----HHHHHHHHHHEEEEE--EEEEEEE-------------HHHHHHHHHHHH------HHHHHHHHHHHHHHHH------HHHHHHHHHHHHH-HHHHHHHHHHHHH----------------
# PSSM pred: ---------EEEEEE--------HHHHHHHHHHH------------------HHHHHHH---------HHHHHHHHHH--EEEEE--------HHHHHHH----------------------------EEEEE------E---HHHHHHHHHHHHHHHHH---EEEEEEE-------------HHHHHHHHHHH-----HHHHHHHHHHHHHHHHHH-----HHHHHHHHHHHHH-HHHHHHHHHHHHH----------------
# output of calc:
# HMM acc:   76.6
# PSSM acc:  82.26
# HMM SOV:   68.25
# PSSM SOV:  77.53
# scopeID:   d2j5ya_
# DSSP:      ---------HHHHHHHHHHHHHHHHHHH-----HHHHHHHHH---HHHHHHHHHHHHHHH-
# HMM pred:  ---------HHHHHHHHHHHHHHHHHHH-----HHHHHHHH----HHHHHHHHHHHHHHH-
# PSSM pred: ----------HHHHHHHHHHHHHHHHHH-----HHHHHHHH----HHHHHHHHHHHHHH--
# output of calc:
# HMM acc:   98.36
# PSSM acc:  95.08
# HMM SOV:   100.0
# PSSM SOV:  99.18
# scopeID:   d2vdra_
# DSSP:      --E-----EEEE---------EEEEEE-----EEEEEEE---E-----E-EEEEEEE-----E---EE-------EEEE--EEEEEE-----E--EEEEE--EEEEEE---EEEEEE--EE---E--EEEEEEE----EEEEE--------HHHHHH-----------E--EEEE----EEEEEE--HHHH--EEEEEEHHHHHHH-------E-----EE----------------EEEEE---------EEEEEE--HHHH--EEEEE-----EEEEEE----------EEEEE--------EEEEEE---EEEE---EEEE--EEEEE-------------EEEE----------EEEEEE--------EEEEEE---------EEEEE-EE--EE-----EEEE-----------EEEEEE--------EEEEEE----EEEEE-E--
# HMM pred:  --------EEEE-------EEEEEEE------EEEEEEE-----------EEEEEEE-------EEEEE------------------------EEEEE------EEEE--------------EEEEEEEEEEE-------------------EEE----------EEEEEEEE------EEEEEE--------EEEEEEEEEEEE------E------------E----------EEEEEE--------EEEEEEE-------EEEEEEE------EEEEE----------EEEEEE-------EEEEE-----------EEEEEEEEEEE-------------EEE----------EEEE-----------EEEEEE-------EEEEEEEE-----------EEEE-----------EE------------EEEEE-----EEEEEE---
# PSSM pred: -------EEEEE-------EEEEEE--------EEEEE-------------EEEEEE-------------------------------------EEEE----EEEEEE---EEEEEE---------EEEEEEE------------------EEE------------EEEEE---------EEEEE--------EEEEE---EEE-----EEEEE-------E-------------EEEEEE---------EEEEEE--------EEEEE------EEEEEE---------EEEEEEE--------EEEE-------------EEEEEEEEEE-------------E---------H-HHHHH-----------EEEE---------EEEEEEE-----------EEEE-----------EEEE-EE-------EEEEE-----EEEEEE---
# output of calc:
# HMM acc:   74.78
# PSSM acc:  73.45
# HMM SOV:   67.12
# PSSM SOV:  67.15
# scopeID:   d2hdza_
# DSSP:      -------HHHHHHHHHHHHHHHH----HHHHHHHHHHHHHH--HHHHHHHHHHHHHHHHHHHHHH-
# HMM pred:  ------HHHHHHHHHHHHHHHHHHHH-HHHHHHHHHHHHHHH-HHH---HHHHHHHHHHHHHHH--
# PSSM pred: -------HHHH------HHHHHHH----HHHHHHHHHHHH-H-HH---HHHHHHHHHHHHH-----
# output of calc:
# HMM acc:   86.36
# PSSM acc:  74.24
# HMM SOV:   74.43
# PSSM SOV:  60.26
# scopeID:   d1us7b_
# DSSP:      -HHHHHHHHHHHHHHHH---HHHHHHHHH-------HHHHHHHHHHHHHHHH---HHHHHHHHHHHHHHHHHHHHHHHH-------HHHHHHHHH---HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH---------HHHHHHH---------HHHHH------HHHHHHHHHHHH--------
# HMM pred:  -HHHHHHHHHHHHHH-----HHHHHHHHHH------HHHH-HHHHHHHHHHH----HHHHHHHHHHHHHHHHHHHH------HHHHHHHHHHH-----HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH-----EEEEE---------HH-----HHHHHHHHH-------HHHHHHHHHHHHH---------
# PSSM pred: -HHHHHHHHHHHHHHHH---HHHHHHHHHH---HHHHHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHHHHHHHH-----HHHHHHHHHH------HHHHHHHHHHHHHHHHHHHHHHHHHHHH-----HHHEEEEE---------------HHHHHHHHHHHHH--------HH-H--------------
# output of calc:
# HMM acc:   78.24
# PSSM acc:  75.13
# HMM SOV:   85.62
# PSSM SOV:  64.74
# scopeID:   d1kl9a1
# DSSP:      --HHHHHHHHHHHHHHHHHHHHHHHHHHH-----HHHHHHHHHH-HHHHHHHH----HHHHHHHHHHHH-----------HHHHHHHHHHHHH-
# HMM pred:  --HHHHHHHHHHHHHHHHHHHHHHHHHHH-------HHHHHHHHHHH-HHHHH-----HHHHHHHHH-------------HHHHHHHHHHHH--
# PSSM pred: --HHHHHHHHHHHHHHHHHHHHHHHHHHH--------HHHHHHHHHHH--HH------HHHHHHHHH-------------HHHHHHHHHHH---
# output of calc:
# HMM acc:   91.49
# PSSM acc:  87.23
# HMM SOV:   91.55
# PSSM SOV:  86.55
# scopeID:   d3mzfa2
# DSSP:      EEEEEEE------EEEEEE-E---EEEEE----EEEEEE-------EEEEEE----EE--E----EEEEEEEEE--EEEEEEEEEE---E-E---
# HMM pred:  ---EEE--------EEEE------EEEEEE---EEEEEE------EEEEEEE-------------EEEEEEEEE---EEEEEEEEE---------
# PSSM pred: ----E----------EE-------EEEEEE---EEEEEE------EEEEEEE--------H----EEEEEEEEE---EEEEEEEEE---------
# output of calc:
# HMM acc:   84.21
# PSSM acc:  80.0
# HMM SOV:   78.0
# PSSM SOV:  74.51
# scopeID:   d2e2aa_
# DSSP:      --HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH---HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--------HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH-
# HMM pred:  --HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH------EEEEEHHHHHHHHHHHHHHHHHHHHHHHHHHHH
# PSSM pred: --HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH------EEEEEE-HHHHHHHHHHHHHHHHHHHHHHHH--
# output of calc:
# HMM acc:   93.27
# PSSM acc:  91.35
# HMM SOV:   99.04
# PSSM SOV:  99.52
# scopeID:   d2hnga1
# DSSP:      --EEE---EEEEEEEEE--HHHHHHH-----EEEEEEEEEEEE----EEEEEEEEEEEEE---EEEEEEEEEEEEEE-----------HHHHHHHHHHHHHHHHHHHHHHHHHHH---------
# HMM pred:  -------EEE----------------------EEE------------EEEEEEEEEEEEE---EEEEEEEEEEEEE------------HHHHHHHHHHHHHHHHHH-HHHHHHHH---------
# PSSM pred: ---E---EEEE---------------------E--------------EEEEEEEEEEEE----EEEEEEEEEEEEEE--E--------HHHHHHHHHHHHHHHHHHHHHHHHHHH---------
# output of calc:
# HMM acc:   76.61
# PSSM acc:  76.61
# HMM SOV:   67.25
# PSSM SOV:  69.94
# scopeID:   d3u9wa1
# DSSP:      -------------EEEEEEEEEEEEE----EEEEEEEEEEEE----EEEEEEEE---EEEEEEE--EE--EEE--------EEEEEEEEEEE----EEEEEEEEE-------EEEE-----------EEEE------------E-------EEEEEEEEEE---EEEE--EEEEEEE------EEEEEEEEEEEE------EEEE-
# HMM pred:  -------------EEEEEEEEEEEE-----EEEEEEEEEEEEE-----EEEEE----EEEEEEE------EEE---------EEEEE---------EEEEEEEEEE-------EEEEEEE-----EEEEEEE-------EEEE--------EEEEEEEEE----EEEE------EEEE-----EEEEEEE-------HHHHEEE--
# PSSM pred: -------------EEEEEEEEEEEEE----EEEEEEEEEEEE-------EEEE----EEEEEEEE------EEE--------EEEEE--------EEEEEEEEEE-------EEEEEEE-------EEEEEE------EEEEE---------EEEEEEEE----EEEE------EEE------EEEEEEE------HHHHHHHE--
# output of calc:
# HMM acc:   79.13
# PSSM acc:  77.67
# HMM SOV:   85.43
# PSSM SOV:  83.73
# scopeID:   d3zyqa1
# DSSP:      -HHHHHHHHH---------HHHHHHHHHHHH-----HHHHHHHHHHHH----HHHHHHHHHHHHHHHHHH-HHHHHHH--HHHHHHHHHHHHH---HHHHHHHHHHHHHHHHH-------HHHHHHHHHHHHH---------
# HMM pred:  --HHHHHHHHHHH-------HHHHHH----EEEEEE----EEEEEEEEE---EEEEEE---EEEEEE--EEEEEE-------E-------------------EEEEEEEE----EEEEEEEEEEEEE----EEEE---EEEEEEEEEEEEE-----EEEEEEEE-----EEEEEEEE------EEEEEEE-----
# PSSM pred: --HHHHHHHHHHH-------HHHHH-----EEEEEE----EEEEEEEEE---EEEEEE---EEEEEE--EEEEEEE--------------HHH---------EEEEEEEE----EEEEEEEEEEEEE----EEEE----EEEEEEEEEEEE-----EEEEEEEEE----EEEEEEEEE-----EEEEEEE-----
# output of calc:
# HMM acc:   87.69
# PSSM acc:  84.1
# HMM SOV:   88.49
# PSSM SOV:  81.18
# scopeID:   d1ijya_
# DSSP:      ----EE------------EE----------HHHHHHHH---HHHHHH-----HHHHHHHHH--E----------E-HHHHHHHHHHHHHHHHH------------------------E----
# HMM pred:  ---EEEE----H------EEE---------HHHHHHHHHHHHHHH-----HHHHHHHHHHHE--------------HHHHHHHHHHHHHHHHH---------------------EEEE----
# PSSM pred: ---EEEEEE---------HEE---------HHHHHH-----EEEEEE-----HHHHHHHHHHHHH-----------HHHHHHHHHHHHHHHHHH--------------------EEE-----
# output of calc:
# HMM acc:   86.07
# PSSM acc:  80.33
# HMM SOV:   81.74
# PSSM SOV:  88.38
# scopeID:   d3ag3j_
# DSSP:      ----HHHHHHHHH------------HHHHHHHHHHHHHHHHHHHHHHHHHHHH-----
# HMM pred:  ---HHHHHHHHH-------EEEE-----HHHHHHHHHHHHHHHHHHHHHHHHHH----
# PSSM pred: --HHHHHHHHHHH------EEEE-----HHHHHHHHHHHHHHHHHHHHHHHHH-----
# output of calc:
# HMM acc:   82.76
# PSSM acc:  84.48
# HMM SOV:   82.15
# PSSM SOV:  81.71
# scopeID:   d1zkea1
# DSSP:      -HHHHHHHHHHHHHHHHHHHHHHHHH---HHHHHHHH--------------HHHHHHHHHHHHHHHHHHHHHH------
# HMM pred:  -HHHHHHHHHHHHHHHHHHHHHHHHH---H--HEEE--------HH--HHHHHHHHHHHHHHHHHHHHHHHHHHHHEE-
# PSSM pred: -HHHHHHHHHHHHHHHHHHHHHHH--------EEEEE---------H-HHHHHHHHHHHHHHHHHHHHHHHHHHHEEE-
# output of calc:
# HMM acc:   79.75
# PSSM acc:  75.95
# HMM SOV:   66.6
# PSSM SOV:  69.35
# scopeID:   d3v5wg_
# DSSP:      -HHHHHHHHHHHHHHH------HHHHHHHHHHHHHH---------------------
# HMM pred:  -HHHHHHHHHHHHHH-------HHHHHHHHHHHHHHH------E-------------
# PSSM pred: -HHHHHHHHHHH-HH-------HHHHHHHHHHHHHHH------E-------------
# output of calc:
# HMM acc:   94.74
# PSSM acc:  92.98
# HMM SOV:   82.05
# PSSM SOV:  72.04
# scopeID:   d3ku3a_
# PSSM pred: --HHHHHHHHH---EEEEEEEEE----HHHHHHHHHHH----------HHHHHHEEEE------HHHHHHHHHHHHHHH----EEEEEEEE------EEEEEEEEE------HH---HH-------
# output of calc:
# HMM acc:   84.92
# PSSM acc:  83.33
# HMM SOV:   73.6
# PSSM SOV:  87.69
# scopeID:   d1h99a1
# DSSP:      --------------HHHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHHHH---------HHHHHHH-HHHHHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHH----
# HMM pred:  --HHHHHHHHH---HHHHHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHHHH--------HHHHHHHHHHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHH---
# PSSM pred: --HHHHHHHHH---HHHHHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHHHH--------HHHHHHHHHHHHHHHHHHHHHHHHH--------HHHHHHHHHHHHHH---
# output of calc:
# HMM acc:   87.83
# PSSM acc:  86.09
# HMM SOV:   79.69
# PSSM SOV:  79.21
# scopeID:   d1vf6a_
# DSSP:      -HHHHHHHHHHHHHH-----HHHHHHHHHHHH-HHHHHHHHHHHHHHHHHHHHHHH--
# HMM pred:  HHHHHHHHHHHHHH------HHHHHHHHHHHH-HHHHHHHHHHHHHHHHHHHHHHH--
# PSSM pred: HHHHHHHHHHHHHH-------HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--
# output of calc:
# HMM acc:   96.55
# PSSM acc:  93.1
# HMM SOV:   98.28
# PSSM SOV:  84.5
# scopeID:   d1p9ya_
# DSSP:      -EEEEEE----EEEEEEEE-HHHHHHHHHHHHHHHH--------------HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH-----EEEEEEEE--------EEEEEEEE-------
# HMM pred:  --EEEEE----EEEEEEEE-HHHHHHHHHHHHHHHH--------------HHHHHHHH-HHHHHHHHHHHHHHHHHHHHHH-----------EE-E------EEEEEEEEEE-EEE-
# PSSM pred: --EEEEE----EEEEEEEE-HHHHHHHHHHHHHHHH-H------------HHHHHHHH-HHHHHHHHHHHHHHHHHHHHHH----------EE--E------EEEEEEEEEE-EEE-
# output of calc:
# HMM acc:   88.03
# PSSM acc:  87.18
# HMM SOV:   72.2
# PSSM SOV:  67.67
# scopeID:   d1oxxk1
# DSSP:      --EEEEEEEE--EEEE--EEE-------EEEEEE----EEEE---------EEEEEEEEEEEEEE--EEEEEEEE------EEEEE--------EEEEEE-----EEEE-
# HMM pred:  ---EEEEEEE--EEEE--EEEEE-----EEEEEEE--EEEE-----------EEEEEEEEEEEE----EEEEEEE---EEEEEE----------EEEEEE----EEE---
# PSSM pred: ----EEEEEE--EEEE--EEEEE-----EEEEEEE---EEE----------EEEEEEEEEEEEE----EEEEEEE---EEEEEEE---------EEEEEE----EEE---
# output of calc:
# HMM acc:   84.55
# PSSM acc:  86.36
# HMM SOV:   92.51
# PSSM SOV:  93.53
# scopeID:   d2ov0a_
# DSSP:      --EE------EE--------EEEEEE--EE---EEEE----EEEEEE-----E--EE---------EE---E---EEEEEEE---EEEEEE-------EEEEEE-
# HMM pred:  ------------------EEEEEEEE-EEEE--EEEEE---EEEEEE------EEEE-------------------EEEEEE----EEEEEE------EEEEEEE
# PSSM pred: ---E---------------EEEEEE--EEEE--EEEEE---EEEEEE----EEEEEE-------------------EEEEEE---EEEEEEEE----EEEEEEEE
# output of calc:
# HMM acc:   81.9
# PSSM acc:  81.9
# HMM SOV:   72.15
# PSSM SOV:  75.73
# scopeID:   d2g3ra1
# DSSP:      -----EEEEE------EEEEEEEEEEE--EEEEEE----EEEEE---EE----
# HMM pred:  -----EEEEEE-----EE-EEEEEE----EEEEEE------EE----EEE---
# PSSM pred: --EEEEEEEEE---------EEEEE-----EEEEE------------EEE---
# output of calc:
# HMM acc:   84.91
# PSSM acc:  67.92
# HMM SOV:   80.47
# PSSM SOV:  65.83
# scopeID:   d1n5ua1
# DSSP:      ----HHHHHHHHH-HHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHHHH----------HHHHHHHHHH----HHHHH----------HHHHHHHHHH---------------HHHHHHHHHH-HHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHHHHHHH
# HMM pred:  --HHHHHHHHHH--HHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHHHHH--------HHHHHHHHHHHHHH---------HHHHHH--------H-HHH-----------------HHHHH--HHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHHHHHHHH--
# PSSM pred: --HHHHHHHHHH-----HHHHHHHHHHHHH----HHHHHHHHHHHHHHHHH-------HHH--HHHHHHHHHHH----------HHHH------HHHHHHHHHH--------------HHHHHHHHH--HHHHHHHHHHHHH-------HHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHHHHHHHH-
# output of calc:
# HMM acc:   82.05
# PSSM acc:  84.62
# HMM SOV:   80.84
# PSSM SOV:  85.03
# scopeID:   d1ppjj_
# DSSP:      --HHHHHHHHHHHHHHH-----HHHH------
# HMM pred:  -HHHHHHHHHHHHHHHH----HHHHHHHHHH-
# PSSM pred: -HHHHHHHHHHHHHHHHH----HHHHHHH---
# output of calc:
# HMM acc:   78.12
# PSSM acc:  84.37
# HMM SOV:   76.25
# PSSM SOV:  88.84
# scopeID:   d2ebsa1
# DSSP:      -EEEE----E---EEEEEE-------EEEEE----EEEEE----EEEE--------------EEEEEEE--EEEEEEEEE---------EEEEE-----EEEEEE-----------------EEE-------EEEE-----EEEE-------EE-------------EEEEEE-------EEEEE-----EEEE-------EE---------HHHHH------------EEEEEEE---EEEEEEE----------EEEEEEE-----EEE-------EE------------EEEEEEE-------EEEEEE----------EEEE------EEEHHHH----------EEE----EE----E-----------E--E--------EEE-------EEEE--EEEEEEEE----EEEE---------
# HMM pred:  --EEE--------EEEEEEE-----EEEEEE---EEEEEE-----EEE--------------EEEEEE------EEEEE----------EEEEEE------EE-----------------EEEEEE-----EEEEEE---EEEEEE----------------------EEEEEE-----EEEEEE----EEEEEE-----EEE------------EEE-------EEE---EEEE-----EEEEE------------EEEEE------EEE-----------------------EEEEEE-----EEEEEE----------EEEEEE------E-----------EEEEEE----EEEEE----EEEEE-----EEE-----------------EEEEEE-----EEEEEE---EEEEE--------
# HMM pred:  -HHHH----HHHHHHHHHHHHHHHHHHHHH------HHHHHHH--HHHHHHHHHHHHHHHHHHHHH---------
# PSSM pred: ---------HHHHHHHHHHHHHHHHHHHH-------HHHHHHH--HHHHHHHHHHHHHHHHHH------------
# output of calc:
# HMM acc:   85.33
# PSSM acc:  93.33
# HMM SOV:   84.52
# PSSM SOV:  97.33
# scopeID:   d2oeba1
# DSSP:      -HHHHHHHHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHHHHHHHH-HHHHHHHHHH---------------------HHHHHHHHHHHHHHHHHHH----------------HHHHHHH--HHHHHHHHHHHHHHHHHHHHHHHHH---
# HMM pred:  ----HHHHHHHHHHHHHHHHHH-------HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH---------HHHHHH-------HHHHHHHHHHHHHHHHH-------------HHHHHHHHH---HHHHHHHHHHHHHHHHHHHHHHHHH---
# PSSM pred: ----HHHHHHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH----------------------HHHHHHHHHHHHHHHHH-------------HHHHHHHHH---HHHHHHHHHHHHHHHHHHHHHHHHH---
# output of calc:
# HMM acc:   86.84
# PSSM acc:  91.45
# HMM SOV:   81.26
# PSSM SOV:  93.64
# scopeID:   d1lkka_
# DSSP:      ------E-----HHHHHHHH---------EEEEE-------EEEEEEEEE---EEEEEEEEEEE-----EE------E--HHHHHHHHHH-----------E---
# HMM pred:  ------------HHHHHHHHHH-------EEEEE-------EEEEEEE------EEEEEEE--------EEE--------HHHHHHHHHH---------E-----
# PSSM pred: ------------HHHHHHHHH-------EEEEEE-------EEEEEE----------------------EEE--------HHHHHHHHHH-------EE------
# output of calc:
# HMM acc:   87.62
# PSSM acc:  79.05
# HMM SOV:   81.67
# PSSM SOV:  69.46
# scopeID:   d1k04a_
# DSSP:      ---------------HHHHHHHHHHHHHHHHHHHH-------HHHHHHHHHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH----
# HMM pred:  ----------------HHHHHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHHHHHHHHH------HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--
# PSSM pred: ---------------HHHHHHHHHHHHHHHHHHH--------HHHHHHHHHHHHHHHHHHHHHHHHH----------EEHHHHHHHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHHHHH--HHHHHHHHHHHHHHHH--
# output of calc:
# HMM acc:   92.96
# PSSM acc:  85.92
# HMM SOV:   98.06
# PSSM SOV:  85.46
# scopeID:   d1vq811
# DSSP:      ----HHHH-------EEE------EEEE----EE----------------------
# HMM pred:  ----HHHH------EEEEEEH--HH-H---------------------HHHHH---
# PSSM pred: -----HHHH------EEEEE-----------------------------HHHH---
# output of calc:
# HMM acc:   71.43
# PSSM acc:  75.0
# HMM SOV:   55.58
# PSSM SOV:  50.6
# scopeID:   d4ac7a_
# DSSP:      ----HHHHHHHHHHHHHHHHHHHHH----E-HHHHHHHHHHHHHHHHHH---HHHHHHH---------E---HHHH--EEEEEEEE--EEEEEEEE----
# HMM pred:  ----HHHHHHHHHHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHH-----HHHHHHHHHHH---------HH-HH--EEE--------EEEEEE----
# PSSM pred: ------HH-HHHHHHHHHHHHHHHH-------HHHHHHHHHHHHHHH-----HHHHHHHHHHHH---H--H-HHHHH--EEEE-------EEEEEE----
# output of calc:
# HMM acc:   82.0
# PSSM acc:  78.0
# HMM SOV:   82.25
# PSSM SOV:  71.37
# scopeID:   d2cs7a1
# DSSP:      ----E-----E-------EE---EEEEEE--EEEEEE-----HHHHHHHHHHHH-
# HMM pred:  ---E------EE----EEE----EEEEE----EEEE------HHHHHHHHHHHH-
# PSSM pred: --EEEE----EE----EE-----EEEEE----EEEE------HHHHHHHHHHH--
# output of calc:
# HMM acc:   83.64
# PSSM acc:  78.18
# HMM SOV:   92.73
# PSSM SOV:  87.55
# scopeID:   d1x9da_
# DSSP:      ---HHHHHHHHHHHHHHHHHHHH-----EEE----EEE------HHHHHHHHHHHH---HHHHHHHHHHHHHH-------EEEHHHHHHHHHHHHHHHHHHH--HHHHHHHHHHHHHH-------------EEE-----EE------EEEHHHHH--HHHHHHHHHHH---HHHHHHHHHHHHHH-----E--E---EEE-----EE---EE------HHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHH-EEE------EEE-EEE--EEE-EEE----HHHHHHHHHHH----HHHHHHHHHHHHHHHHHHH---------EEE------------E-------E----HHHHHHHHHHHHH---HHHHHHHHHHHHHHHH-E-----E--E----------E---E-HHHHH-HHHHHHHHH----------EEE-----EEE--
# HMM pred:  -HHHHHHHHHHHHHHHHHHHHHH------EEE------------EHHHHHHHHHHH---HHHHHHHHHHHHH---------E-EEEEHHHHHHHHHHHHH-----HHHHHHHHHHHHHH------------EEE----------------HHHHHHHHHHHHHHHHH----HHHHHHHHHHHHHHHH----------EEE----------EEEE-----HHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHH---------EEE------EE------HHHHHHHHHHHHHH-----HHHHHHHHHHHHHHHHHHH-------EEEEEE----------------------HHHHHHHHHHHHH---HHHHHHHHHHHHHHHHHH-------EEE----------E------HHHHHHHHHHHH------------EEE----------
# PSSM pred: -HHHHHHHHHHHHHHHHHHHHHH------EEEE-----E----EEEEE------HE---HHHHHHHHHHH-----------E------------HHHHHHH----HHHHHHHHHHHHHHHH----------EE--------------------H---HH---E---------HHHHHHHHHHHHHHH--------EEEEE-----EE----EE--------------EEE-------HHHHHHHHHHHHHHHHH---------EEEEE------------HHHHHHHHHHH--------HHHHHHHHHHHHHHHHHH---------EEEE---------EEE-----------------EEEEEEE----HHHHHHHHHHHHHHHHHH-------------------------HHHHHHHHHHHHEE-----------EEEE---------
# output of calc:
# HMM acc:   83.81
# PSSM acc:  70.07
# HMM SOV:   78.94
# PSSM SOV:  65.79
# scopeID:   d1v30a_
# DSSP:      -EEEEE-----------------EEEEEEEEEEEEEEE---EEEEEEEEEEEEEEEEE-HHHHHHH--------EEEEEE------EEEEEE------EE-------HHHHHHHHHH-
# HMM pred:  --EEEEE----------HH-----EEE-EEEE-EE-------EEE----EEEEEEEEE-HHHHHHHHH------EEEEEEEEEEEEEEEEEE-------------HHHHHHH------
# PSSM pred: -EEEEEE----------HH-----EE--EEE---EE------EEE----EEEEEEEE--HHHHHHHHH------EEEEEEE----EEEEEE--------------HHHHHHHH-----
# output of calc:
# HMM acc:   72.88
# PSSM acc:  74.58
# HMM SOV:   51.98
# PSSM SOV:  57.17
# scopeID:   d1ko7a1
# DSSP:      --EHHHHHHHH--EEEE-------E-----EE--HHHH-----------EEEE-HHHHHHHHH--HHHH--HHHHH-------EEE-------HHHHHHHHH----EEE----HHHHHHHHHHHHHHH-
# HMM pred:  ---HHHHHHH---EEEE------EEEEE-------HHHH-HH-------EEEEEHHHHHHHH---HHHHHHHHHHHH-----EEEEE------HHHHHHHHH---EEEEE---HHHHHHHHHHHHHH--
# PSSM pred: --HHHHHHHH---EEE--------EEE-------HHHHHHH--------EEEEEHHHHHHHH---HHHHHHHHHHHH-----EEEEE------HHHHHHHHH---EEEEE---HHHHHHHHHHHHHH--
# output of calc:
# HMM acc:   82.95
# PSSM acc:  84.5
# HMM SOV:   80.2
# PSSM SOV:  87.3
# scopeID:   d1nkia_
# DSSP:      -EEEEEEEEEEE--HHHHHHHHHH----EEEEEE--EEEEEE--EEEEEEE------------EEEEEE-HHHHHHHHHHHHH----EEE-------EEEEE-----EEEEE---HHHHHHHHHH------EE-
# HMM pred:  ------EEEEE---HHHHHHHHHHH---EEEE-----EEEE-----EEEEE------------EEEEEE--HHHHHHHHHHHH---EEEE------EEEEEE-----EEEEEE-----HHHHH-H---------
# PSSM pred: ------EEEEEE--HHHHHHHHHHHH-----------EEEEEE--EEEEE-------------EEEEEE-HHHHHHHHHHHHH-----EE------EEEEEE-----EEEEEE--HHHHHHH-HH------EE-
# output of calc:
# HMM acc:   82.84
# PSSM acc:  84.33
# HMM SOV:   83.8
# PSSM SOV:  85.61
# scopeID:   d1j5ya2
# DSSP:      ---EEEEEEEE-----HHHHHHHHHH---EEEEEEEEE---EEEEEEEEE--HHHHHHHHHHHHH------------EEEEEEEE--HHHHHHHHHHHHH---E---
# HMM pred:  ---EEEEEEEE--HHHHHHHHHHHHH---EEEEEEEE-----EEEEE-----HHHHHHHHHHHH-----HHHHH----EEEEEEE--HHHHHHHHHHHHH-------
# PSSM pred: ---EEEEEEEE---HHHHHHHHHHHH---EEEEEEEE------EEEEEEE--HHHHHHHHHHHH-------EH-----EEEEEE---HHHHHHHHHHHHHH------
# output of calc:
# HMM acc:   85.05
# PSSM acc:  88.79
# HMM SOV:   80.83
# PSSM SOV:  86.67
# scopeID:   d3ksna_
# DSSP:      -HHHHHHHHHH---EEEEEEEEEEE---EEEEEEEEE---EEEEEEEE---EEEEE---EEEEEE----EEEEEE--------HHHHHHH--HHHH--EEEEEE--EEEEEE------EEEEEEEE-----EEEEEEEE----EEEEEEEEEEE----------------EEEE---
# HMM pred:  -HHHHHHHHHH-----EEEEEEEE----EEEEEEEEE----EEEEE-----EEEEE---EEEEEE----EEEE----------HHHHH---------EEEEEE--EEEEEEEE-----EEEEEEEEE----EEEEEEEE----EEEEEEEEE---------EEE------EEE----
# PSSM pred: -HHHHHHHHHHH---EEEEEEEEE---EEEEEEEEEEE---EEEEE-----EEEEEE--EEEEEE----EEEE---------HHHHHHH------H---EE-----EEEEEEE-----EEEEEEEEE----EEEEEEEE----EEEEEEEEEE--------EEEE-----EE-----
# output of calc:
# HMM acc:   85.88
# PSSM acc:  83.62
# HMM SOV:   88.07
# PSSM SOV:  85.55
# scopeID:   d1z0pa1
# DSSP:      --HHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--HHHHHHHHHHHHHHHHHHHHHHHHHHHHH----------
# HMM pred:  ---HHHHHHHHHHHHHHHHEE-HH-HHHHHHHHHHHHH-HHHHH-----HHHHHHHHHH-HHH----------
# PSSM pred: ---HHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHHH--H-HHHHHHHH-H--HHH----------
# output of calc:
# HMM acc:   80.82
# PSSM acc:  87.67
# HMM SOV:   37.24
# PSSM SOV:  36.86
# scopeID:   d1vr4a1
# DSSP:      -EE-----E--E---EEEEEEEEEEEE-HHHHH--------EEE----------HHHHHHHHHHHHHHHHH----EEEEEEEEEEEE---EEEEEEEEEEEE-
# HMM pred:  -EEEE-------EEEEEE-EEEEEEEEE--HHHHHHHHHHHHH---HHHHHHHHHHHHHHHHHHHHHHHHHH---EEEEEEEEEEE----EEEEEEE--EEEE
# PSSM pred: EEEEE-------EEEEEEEEEEEEEEEE----HHHHHHHHHHHH--HHHHHHHHHHHHHHHHHHHHHHHHH-----EEEEEEEEE-H---HHEEEEE--EEEE
# output of calc:
# HMM acc:   66.02
# PSSM acc:  61.17
# HMM SOV:   60.13
# PSSM SOV:  59.2
# scopeID:   d1vkma_
# DSSP:      ----------EEE-------EEEE--HHHH----HHHHHHHHHHHHHHHHHH--EEEEEEEE--EEEE---HHHHHHHHHH--EEE----HHHHHHH---EEE-HHHHHHHHHHH---EEE---E--E------E-HHHHHH----EEEEE-EE-----HHHHHHHHHH----EEEE---E--E--E-----E--EE--HHHHHHHHHHHHH-----EEEEE----------HHHHHHHHH----------HHHHHHHHHHHH---HHHHHHHHHHHHHHHHHHHHHHHH-
# HMM pred:  ----EE--HHHHHHHHH----EEHHHHHH-------HHHHHHHHHHHHHHH----EEEEEEE--EEEE---HHHHHHHH-----EE----HHHHHH-----HHHHHHHHHHHHH----EEEE------------HHHHHHHH-----EEEE--------HHHHHHHHHH--EEEEEEE------EEE------------HHHHHHHHHHHHH------EEEEE---------HHHHHHHHHHHHH-------HHHHHHHHHHH----HHHHHHHHHHHHHHHHHHHHHHH-
# PSSM pred: --------HHHHHHHH----EEEEE-----------HHHHHHHHHHHHHHH----EEEEEEE--EEEEE--HHHHHHH-----HHH----HHHHHH------HHHHHHHHHHHH----EEE-----------------HHH-----EEEEE-----HH-HHHHHHHHH---EEEEEE------EEE-------------HHHHHHHHHHHHH------EEEE----------HHHHHHHHHHHHHH------HHHHHHHHHHH----HHHHHHHHHHHHHHHHHHHHHHH-
# output of calc:
# HMM acc:   81.1
# PSSM acc:  80.07
# HMM SOV:   80.43
# PSSM pred: -----------------------EE-HHHHHH------EEE-----EEEE--H-H---HHHHHHHHHHHHHHHH-----------EEEEEE--EEEE--------EEEEEE------
# output of calc:
# HMM acc:   86.32
# PSSM acc:  74.36
# HMM SOV:   84.53
# PSSM SOV:  62.69

# %% [markdown]
# # SNNS

# %%
for i in range(1,8):

    # read SCOPe domain names into a list
    data_folder="/cluster/gjb_lab/2472402/data/cross-val/train_patterns/cv%d/" % i
    scopeIDs=[filename.rstrip('.pkl') for filename in os.listdir(data_folder)]
    jnet_folder="/homes/adrozdetskiy/Projects/jpredJnet231ReTrainingSummaryTable/data/training/"
    
    results=[]
    alignments=[]

    for scopeID in scopeIDs:
        
        jnet_path=jnet_folder+scopeID+'.jnet'
        with open(jnet_path,'r') as f:
            lines=f.read().splitlines()
            hmm_pred=lines[6].replace("JNETHMM:","").replace(",","")
            pssm_pred=lines[7].replace("JNETPSSM:","").replace(",","")
        
        data_folder="/homes/adrozdetskiy/Projects/jpredJnet231ReTrainingSummaryTable/data/training/"
        sec_file=data_folder+scopeID+'.sec'

        assert os.path.exists(sec_file)
        with open(sec_file,'r') as f:
            sec=f.read().splitlines()
            seq=sec[0].replace("SEQUENCE:","").replace(",","")
            dssp=sec[1].replace("DSSP:","").replace("B","E").replace("I","-").replace("G","-").replace("S","-").replace("T","-").replace(",","")

        # check sanity of input to calc()
        # print("scopeID:   %s" % scopeID)
        # print("DSSP:      %s" % dssp)
        # print("HMM pred:  %s" % hmm_pred)
        # print("PSSM pred: %s" % pssm_pred)

        sov_folder='/cluster/gjb_lab/2472402/sov/snns/20Aug/cv%d/' % i
        assert os.path.exists(sov_folder)
        (hmm_acc,pssm_acc,hmm_sov,pssm_sov)=calc(sov_folder,scopeID,seq,dssp,hmm_pred,pssm_pred)

        # check sanity of output of calc()
        # print("output of calc: ")
        # print("HMM acc:   %s" % hmm_acc)
        # print("PSSM acc:  %s" % pssm_acc)
        # print("HMM SOV:   %s" % hmm_sov)
        # print("PSSM SOV:  %s" % pssm_sov)

        #store results
        results.append((scopeID,hmm_acc,pssm_acc,hmm_sov,pssm_sov))
        alignments.append((scopeID,seq,dssp,hmm_pred,pssm_pred))


    # output results to csv file
    out_file="/cluster/gjb_lab/2472402/results/snns/20Aug/cv%i_scores.csv" % i
    with open(out_file,'w+') as f:
        f.write("scopeID,HMM_acc,PSSM_acc,HMM_sov,PSSM_sov\n")
        for (scopeID,hmm_acc,pssm_acc,hmm_sov,pssm_sov) in results:
            line="%s,%.2f,%.2f,%.2f,%.2f\n" % (scopeID,hmm_acc,pssm_acc,hmm_sov,pssm_sov)
            f.write(line)

    # write alignments to kerasnet file
    align_file="/cluster/gjb_lab/2472402/results/snns/20Aug/cv%i.knet" % i
    with open(align_file,'w+') as f:
        for (scopeID, seq,dssp,hmm_pred,pssm_pred) in alignments:
            f.write("scopeID   : %s\n" % scopeID)
            f.write("sequence  : %s\n" % seq)
            f.write("DSSP      : %s\n" % dssp)
            f.write("HMM_pred  : %s\n" % hmm_pred)
            f.write("PSSM_pred : %s\n" % pssm_pred)
